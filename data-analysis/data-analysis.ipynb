# %% [markdown]
# <center><h1>Data Analysis Portion</h1></center>
#
# ## Contents:
# 1. [Data Cleaning](#Data-Cleaning)
# 2. [EPA](#Exploratory-Data-Analysis)
# 3. [Model Creation](#Model-Creation)

# %% [markdown]
# <center><h1>Data Cleaning</h1></center>
#
# In this step, I prepare the data to make it ready for visualization.

# %%
import pandas as pd
import numpy as np

# %%
DATASET_PATH = "./data/output.csv"
COLUMN_NAMES = ['price', 'year_model', 'mileage', 'fuel_type', 'mark', 'model', 'fiscal_power', 'sector', 'type', 'city'] 
df = pd.read_csv(DATASET_PATH, names=COLUMN_NAMES)
df.head()
# Out:
#         price         year_model                        mileage  \
# 0  135 000 DH  Année-Modèle:2013  Kilométrage:160 000 - 169 999
# 1   53 000 DH  Année-Modèle:2008    Kilométrage:35 000 - 39 999
# 2   59 000 DH  Année-Modèle:2007  Kilométrage:180 000 - 189 999
# 3   88 000 DH  Année-Modèle:2010    Kilométrage:35 000 - 39 999
# 4   60 000 DH  Année-Modèle:2009  Kilométrage:130 000 - 139 999
#
#                    fuel_type                  mark          model  \
# 0   Type de carburant:Diesel        Marque:Peugeot     Modèle:508
# 1   Type de carburant:Diesel        Marque:Renault    Modèle:Clio
# 2   Type de carburant:Diesel        Marque:Citroen      Modèle:C3
# 3   Type de carburant:Diesel  Marque:Mercedes-Benz     Modèle:220
# 4  Type de carburant:Essence           Marque:Ford  Modèle:Fiesta
#
#              fiscal_power            sector                  type     city
# 0     Puissance fiscale:-                 -  Type:Voitures, Offre   Temara
# 1     Puissance fiscale:-                 -  Type:Voitures, Offre     Safi
# 2  Puissance fiscale:6 CV  Secteur:oued_fes  Type:Voitures, Offre      Fès
# 3     Puissance fiscale:-                 -  Type:Voitures, Offre    Nador
# 4  Puissance fiscale:7 CV     Secteur:saies  Type:Voitures, Offre      Fès

# %%
df.describe()
# Out:
#             price         year_model                        mileage  \
# count        8669               8669                           8669
# unique        423                 46                             49
# top     55 000 DH  Année-Modèle:2013  Kilométrage:200 000 - 249 999
# freq          184                633                            739
#
#                        fuel_type            mark         model  \
# count                       8669            8669          8669
# unique                         9              60           491
# top     Type de carburant:Diesel  Marque:Renault  Modèle:Logan
# freq                        6159            1277           314
#
#                fiscal_power sector                  type         city
# count                  8669   8669                  8669         8664
# unique                   31    476                     6          129
# top     Puissance fiscale:-      -  Type:Voitures, Offre   Casablanca
# freq                   5717   3634                  8664         2817

# %% [markdown]
# <br>
# As one can see, the data is not clean.<br>
# We need to clean the data from all columns, except city.

# %% [markdown]
# ### Fix Price Column
# Some rows __do not__ have prices. We need to eliminate those.

# %%
len( np.where(df.price.str.contains("DH").values == False) )
# Out:
# 1

# %%
df = df[df.price.str.contains("DH") == True]               # delete elements without 'DH' (without a price)
df.price = df.price.map(lambda price: price.rstrip(' DH')) # eliminate ' DH'
df.price = df.price.str.replace(' ', '') # remove white space between digits
df.price = pd.to_numeric(df.price, errors='coerce', downcast='integer') #set type to int
df.head()
# Out:
#     price         year_model                        mileage  \
# 0  135000  Année-Modèle:2013  Kilométrage:160 000 - 169 999
# 1   53000  Année-Modèle:2008    Kilométrage:35 000 - 39 999
# 2   59000  Année-Modèle:2007  Kilométrage:180 000 - 189 999
# 3   88000  Année-Modèle:2010    Kilométrage:35 000 - 39 999
# 4   60000  Année-Modèle:2009  Kilométrage:130 000 - 139 999
#
#                    fuel_type                  mark          model  \
# 0   Type de carburant:Diesel        Marque:Peugeot     Modèle:508
# 1   Type de carburant:Diesel        Marque:Renault    Modèle:Clio
# 2   Type de carburant:Diesel        Marque:Citroen      Modèle:C3
# 3   Type de carburant:Diesel  Marque:Mercedes-Benz     Modèle:220
# 4  Type de carburant:Essence           Marque:Ford  Modèle:Fiesta
#
#              fiscal_power            sector                  type     city
# 0     Puissance fiscale:-                 -  Type:Voitures, Offre   Temara
# 1     Puissance fiscale:-                 -  Type:Voitures, Offre     Safi
# 2  Puissance fiscale:6 CV  Secteur:oued_fes  Type:Voitures, Offre      Fès
# 3     Puissance fiscale:-                 -  Type:Voitures, Offre    Nador
# 4  Puissance fiscale:7 CV     Secteur:saies  Type:Voitures, Offre      Fès

# %%
## Verify there is no NaN
df.price.isnull().values.sum()
# Out:
# 0

# %% [markdown]
# ### Fix `Year_model`

# %%
df.year_model = df.year_model.str.replace('Année-Modèle:', '')
df.head()
# Out:
#     price year_model                        mileage  \
# 0  135000       2013  Kilométrage:160 000 - 169 999
# 1   53000       2008    Kilométrage:35 000 - 39 999
# 2   59000       2007  Kilométrage:180 000 - 189 999
# 3   88000       2010    Kilométrage:35 000 - 39 999
# 4   60000       2009  Kilométrage:130 000 - 139 999
#
#                    fuel_type                  mark          model  \
# 0   Type de carburant:Diesel        Marque:Peugeot     Modèle:508
# 1   Type de carburant:Diesel        Marque:Renault    Modèle:Clio
# 2   Type de carburant:Diesel        Marque:Citroen      Modèle:C3
# 3   Type de carburant:Diesel  Marque:Mercedes-Benz     Modèle:220
# 4  Type de carburant:Essence           Marque:Ford  Modèle:Fiesta
#
#              fiscal_power            sector                  type     city
# 0     Puissance fiscale:-                 -  Type:Voitures, Offre   Temara
# 1     Puissance fiscale:-                 -  Type:Voitures, Offre     Safi
# 2  Puissance fiscale:6 CV  Secteur:oued_fes  Type:Voitures, Offre      Fès
# 3     Puissance fiscale:-                 -  Type:Voitures, Offre    Nador
# 4  Puissance fiscale:7 CV     Secteur:saies  Type:Voitures, Offre      Fès

# %%
df[df.year_model.map(lambda x: x.isdigit() == False)]
# Out:
#        price           year_model                        mileage  \
# 140    37000                    -                  Kilométrage:-
# 154    60000                    -                  Kilométrage:-
# 384    95000                    -                  Kilométrage:-
# 448    15000  1980 ou plus ancien  Kilométrage:130 000 - 139 999
# 458   160000  1980 ou plus ancien  Kilométrage:160 000 - 169 999
# 567    36000                    -                  Kilométrage:-
# 587   400000                    -                  Kilométrage:-
# 1017   40500                    -                  Kilométrage:-
# 1073  730000                    -                  Kilométrage:-
# 1118   15000  1980 ou plus ancien          Kilométrage:0 - 4 999
# 1140  320000                    -                  Kilométrage:-
# 1177   55000                    -                  Kilométrage:-
# 1237   40500                    -                  Kilométrage:-
# 1413   75000                    -                  Kilométrage:-
# 1498  145000                    -  Kilométrage:200 000 - 249 999
# 1896   30000                    -                  Kilométrage:-
# 1935   60000                    -                  Kilométrage:-
# 2002    9000  1980 ou plus ancien          Kilométrage:0 - 4 999
# 2018   80000  1980 ou plus ancien  Kilométrage:190 000 - 199 999
# 2138  220000                    -                  Kilométrage:-
# 2298   17000  1980 ou plus ancien  Kilométrage:450 000 - 499 999
# 2476  150000                    -                  Kilométrage:-
# 2481   21000  1980 ou plus ancien    Kilométrage:65 000 - 69 999
# 2669  250000                    -                  Kilométrage:-
# 2720   50000                    -                  Kilométrage:-
# 2898   37000                    -                  Kilométrage:-
# 2954   90000  1980 ou plus ancien    Kilométrage:10 000 - 14 999
# 3236   35000                    -                  Kilométrage:-
# 3328   94000                    -                  Kilométrage:-
# 3415   80000                    -                  Kilométrage:-
# ...      ...                  ...                            ...
# 7180   95000                    -                  Kilométrage:-
# 7187  135000                    -                  Kilométrage:-
# 7192   45000  1980 ou plus ancien  Kilométrage:200 000 - 249 999
# 7236   70000                    -                  Kilométrage:-
# 7247  170000                    -                  Kilométrage:-
# 7277   72000                    -                  Kilométrage:-
# 7342   30000  1980 ou plus ancien    Kilométrage:Plus de 500 000
# 7465   57000                    -                  Kilométrage:-
# 7567   28000  1980 ou plus ancien          Kilométrage:0 - 4 999
# 7680   40000  1980 ou plus ancien  Kilométrage:100 000 - 109 999
# 7681   40000  1980 ou plus ancien  Kilométrage:100 000 - 109 999
# 7790   90000                    -                  Kilométrage:-
# 7792   52000                    -                  Kilométrage:-
# 7835   32000                    -                  Kilométrage:-
# 7861   38000                    -                  Kilométrage:-
# 7874   65000                    -                  Kilométrage:-
# 7920   62000                    -                  Kilométrage:-
# 8018   25000  1980 ou plus ancien    Kilométrage:20 000 - 24 999
# 8069   10000  1980 ou plus ancien    Kilométrage:15 000 - 19 999
# 8084   93000                    -                  Kilométrage:-
# 8106   60000                    -                  Kilométrage:-
# 8189   99000                    -                  Kilométrage:-
# 8211   97000                    -                  Kilométrage:-
# 8239   25000                    -                  Kilométrage:-
# 8284  130000  1980 ou plus ancien  Kilométrage:130 000 - 139 999
# 8290   57000                    -                  Kilométrage:-
# 8403   60000                    -                  Kilométrage:-
# 8559   59000                    -                  Kilométrage:-
# 8588   12000  1980 ou plus ancien    Kilométrage:45 000 - 49 999
# 8635   30000                    -                  Kilométrage:-
#
#                       fuel_type                  mark  \
# 140         Type de carburant:-              Marque:-
# 154         Type de carburant:-              Marque:-
# 384         Type de carburant:-              Marque:-
# 448   Type de carburant:Essence        Marque:Renault
# 458   Type de carburant:Essence         Marque:Jaguar
# 567         Type de carburant:-              Marque:-
# 587         Type de carburant:-              Marque:-
# 1017        Type de carburant:-              Marque:-
# 1073        Type de carburant:-              Marque:-
# 1118  Type de carburant:Essence        Marque:Renault
# 1140        Type de carburant:-              Marque:-
# 1177        Type de carburant:-              Marque:-
# 1237        Type de carburant:-              Marque:-
# 1413        Type de carburant:-              Marque:-
# 1498   Type de carburant:Diesel     Marque:Land Rover
# 1896        Type de carburant:-              Marque:-
# 1935        Type de carburant:-              Marque:-
# 2002  Type de carburant:Essence        Marque:Renault
# 2018   Type de carburant:Diesel        Marque:Peugeot
# 2138        Type de carburant:-              Marque:-
# 2298   Type de carburant:Diesel  Marque:Mercedes-Benz
# 2476        Type de carburant:-              Marque:-
# 2481   Type de carburant:Diesel           Marque:Audi
# 2669        Type de carburant:-              Marque:-
# 2720        Type de carburant:-              Marque:-
# 2898        Type de carburant:-              Marque:-
# 2954   Type de carburant:Diesel        Marque:Renault
# 3236        Type de carburant:-              Marque:-
# 3328        Type de carburant:-              Marque:-
# 3415        Type de carburant:-              Marque:-
# ...                         ...                   ...
# 7180        Type de carburant:-              Marque:-
# 7187        Type de carburant:-              Marque:-
# 7192   Type de carburant:Diesel  Marque:Mercedes-Benz
# 7236        Type de carburant:-              Marque:-
# 7247        Type de carburant:-              Marque:-
# 7277        Type de carburant:-              Marque:-
# 7342  Type de carburant:Essence        Marque:Renault
# 7465        Type de carburant:-              Marque:-
# 7567   Type de carburant:Diesel          Marque:Rover
# 7680   Type de carburant:Diesel        Marque:Peugeot
# 7681   Type de carburant:Diesel        Marque:Peugeot
# 7790        Type de carburant:-              Marque:-
# 7792        Type de carburant:-              Marque:-
# 7835        Type de carburant:-              Marque:-
# 7861        Type de carburant:-              Marque:-
# 7874        Type de carburant:-              Marque:-
# 7920        Type de carburant:-              Marque:-
# 8018   Type de carburant:Diesel  Marque:Mercedes-Benz
# 8069   Type de carburant:Diesel     Marque:Volkswagen
# 8084        Type de carburant:-              Marque:-
# 8106        Type de carburant:-              Marque:-
# 8189        Type de carburant:-              Marque:-
# 8211        Type de carburant:-              Marque:-
# 8239        Type de carburant:-              Marque:-
# 8284   Type de carburant:Diesel  Marque:Mercedes-Benz
# 8290        Type de carburant:-              Marque:-
# 8403        Type de carburant:-              Marque:-
# 8559        Type de carburant:-              Marque:-
# 8588   Type de carburant:Diesel     Marque:Volkswagen
# 8635        Type de carburant:-              Marque:-
#
#                          model             fiscal_power  \
# 140                   Modèle:-      Puissance fiscale:-
# 154                   Modèle:-      Puissance fiscale:-
# 384                   Modèle:-      Puissance fiscale:-
# 448                 Modèle:R18      Puissance fiscale:-
# 458                  Modèle:XJ      Puissance fiscale:-
# 567                   Modèle:-      Puissance fiscale:-
# 587                   Modèle:-      Puissance fiscale:-
# 1017                  Modèle:-      Puissance fiscale:-
# 1073                  Modèle:-      Puissance fiscale:-
# 1118                 Modèle:R4      Puissance fiscale:-
# 1140                  Modèle:-      Puissance fiscale:-
# 1177                  Modèle:-      Puissance fiscale:-
# 1237                  Modèle:-      Puissance fiscale:-
# 1413                  Modèle:-      Puissance fiscale:-
# 1498  Modèle:Range Rover Sport  Puissance fiscale:15 CV
# 1896                  Modèle:-      Puissance fiscale:-
# 1935                  Modèle:-      Puissance fiscale:-
# 2002                 Modèle:R5      Puissance fiscale:-
# 2018              Modèle:Tepee      Puissance fiscale:-
# 2138                  Modèle:-      Puissance fiscale:-
# 2298                Modèle:240   Puissance fiscale:8 CV
# 2476                  Modèle:-      Puissance fiscale:-
# 2481                 Modèle:80   Puissance fiscale:6 CV
# 2669                  Modèle:-      Puissance fiscale:-
# 2720                  Modèle:-      Puissance fiscale:-
# 2898                  Modèle:-      Puissance fiscale:-
# 2954             Modèle:Kangoo      Puissance fiscale:-
# 3236                  Modèle:-      Puissance fiscale:-
# 3328                  Modèle:-      Puissance fiscale:-
# 3415                  Modèle:-      Puissance fiscale:-
# ...                        ...                      ...
# 7180                  Modèle:-      Puissance fiscale:-
# 7187                  Modèle:-      Puissance fiscale:-
# 7192                Modèle:220   Puissance fiscale:8 CV
# 7236                  Modèle:-      Puissance fiscale:-
# 7247                  Modèle:-      Puissance fiscale:-
# 7277                  Modèle:-      Puissance fiscale:-
# 7342                 Modèle:R4      Puissance fiscale:-
# 7465                  Modèle:-      Puissance fiscale:-
# 7567                 Modèle:75      Puissance fiscale:-
# 7680                Modèle:504      Puissance fiscale:-
# 7681                Modèle:504      Puissance fiscale:-
# 7790                  Modèle:-      Puissance fiscale:-
# 7792                  Modèle:-      Puissance fiscale:-
# 7835                  Modèle:-      Puissance fiscale:-
# 7861                  Modèle:-      Puissance fiscale:-
# 7874                  Modèle:-      Puissance fiscale:-
# 7920                  Modèle:-      Puissance fiscale:-
# 8018                Modèle:240      Puissance fiscale:-
# 8069               Modèle:Golf      Puissance fiscale:-
# 8084                  Modèle:-      Puissance fiscale:-
# 8106                  Modèle:-      Puissance fiscale:-
# 8189                  Modèle:-      Puissance fiscale:-
# 8211                  Modèle:-      Puissance fiscale:-
# 8239                  Modèle:-      Puissance fiscale:-
# 8284               Modèle:207D  Puissance fiscale:10 CV
# 8290                  Modèle:-      Puissance fiscale:-
# 8403                  Modèle:-      Puissance fiscale:-
# 8559                  Modèle:-      Puissance fiscale:-
# 8588               Modèle:Golf      Puissance fiscale:-
# 8635                  Modèle:-      Puissance fiscale:-
#
#                          sector                  type          city
# 140                           -  Type:Voitures, Offre        Arfoud
# 154                           -  Type:Voitures, Offre        Dakhla
# 384                           -  Type:Voitures, Offre       Guercif
# 448        Secteur:centre_ville  Type:Voitures, Offre    Casablanca
# 458                           -  Type:Voitures, Offre    Casablanca
# 567                           -  Type:Voitures, Offre         Rabat
# 587                           -  Type:Voitures, Offre    Casablanca
# 1017                          -  Type:Voitures, Offre       Skhirat
# 1073         Secteur:hay_chmaou  Type:Voitures, Offre          Salé
# 1118      Secteur:autre_secteur  Type:Voitures, Offre         Rabat
# 1140      Secteur:administratif  Type:Voitures, Offre        Tanger
# 1177                          -  Type:Voitures, Offre    Casablanca
# 1237                          -  Type:Voitures, Offre       Skhirat
# 1413                          -  Type:Voitures, Offre    Casablanca
# 1498        Secteur:ouled_oujih  Type:Voitures, Offre       Kénitra
# 1896                          -  Type:Voitures, Offre         Nador
# 1935                          -  Type:Voitures, Offre    Casablanca
# 2002           Secteur:selouane  Type:Voitures, Offre         Nador
# 2018                          -  Type:Voitures, Offre         Rabat
# 2138                          -  Type:Voitures, Offre           Fès
# 2298          Secteur:bernoussi  Type:Voitures, Offre    Casablanca
# 2476                          -  Type:Voitures, Offre    Mohammedia
# 2481        Secteur:oued_ourika  Type:Voitures, Offre     Marrakech
# 2669                          -  Type:Voitures, Offre      Bir Jdid
# 2720                          -  Type:Voitures, Offre    Casablanca
# 2898                          -  Type:Voitures, Offre        Dakhla
# 2954                          -  Type:Voitures, Offre        Meknès
# 3236                          -  Type:Voitures, Offre        Tanger
# 3328                          -  Type:Voitures, Offre    Casablanca
# 3415             Secteur:hassan  Type:Voitures, Offre         Rabat
# ...                         ...                   ...           ...
# 7180                          -  Type:Voitures, Offre      Ait Baha
# 7187       Secteur:centre_ville  Type:Voitures, Offre    Mohammedia
# 7192      Secteur:autre_secteur  Type:Voitures, Offre         Rabat
# 7236                          -  Type:Voitures, Offre    Casablanca
# 7247                          -  Type:Voitures, Offre    Casablanca
# 7277                          -  Type:Voitures, Offre    Casablanca
# 7342     Secteur:toute_la_ville  Type:Voitures, Offre        Tiznit
# 7465                          -  Type:Voitures, Offre       Kénitra
# 7567     Secteur:toute_la_ville  Type:Voitures, Offre    Al Hoceïma
# 7680       Secteur:route_jerada  Type:Voitures, Offre         Oujda
# 7681       Secteur:route_jerada  Type:Voitures, Offre         Oujda
# 7790                          -  Type:Voitures, Offre        Agadir
# 7792                          -  Type:Voitures, Offre          Salé
# 7835                          -  Type:Voitures, Offre        Agadir
# 7861                          -  Type:Voitures, Offre    Casablanca
# 7874                          -  Type:Voitures, Offre   Béni Mellal
# 7920                          -  Type:Voitures, Offre    Errachidia
# 8018                          -  Type:Voitures, Offre        Meknès
# 8069  Secteur:hay_moulay_rachid  Type:Voitures, Offre    Casablanca
# 8084                          -  Type:Voitures, Offre           Fès
# 8106                          -  Type:Voitures, Offre        Meknès
# 8189                          -  Type:Voitures, Offre     Marrakech
# 8211                          -  Type:Voitures, Offre        Agadir
# 8239                          -  Type:Voitures, Offre    Casablanca
# 8284                          -  Type:Voitures, Offre        Dakhla
# 8290                          -  Type:Voitures, Offre        Meknès
# 8403                          -  Type:Voitures, Offre           Fès
# 8559                          -  Type:Voitures, Offre           Fès
# 8588                          -  Type:Voitures, Offre    Casablanca
# 8635                          -  Type:Voitures, Offre          Salé
#
# [116 rows x 10 columns]

# %% [markdown]
# __NOTE__: Not all year_model values are integers.

# %%
df.year_model = df.year_model.str.replace(' ou plus ancien', '') # eliminate string
df[df.year_model.map(lambda x: x.isdigit() == False)]            # check rest of the values
# Out:
#         price year_model                        mileage  \
# 140     37000          -                  Kilométrage:-
# 154     60000          -                  Kilométrage:-
# 384     95000          -                  Kilométrage:-
# 567     36000          -                  Kilométrage:-
# 587    400000          -                  Kilométrage:-
# 1017    40500          -                  Kilométrage:-
# 1073   730000          -                  Kilométrage:-
# 1140   320000          -                  Kilométrage:-
# 1177    55000          -                  Kilométrage:-
# 1237    40500          -                  Kilométrage:-
# 1413    75000          -                  Kilométrage:-
# 1498   145000          -  Kilométrage:200 000 - 249 999
# 1896    30000          -                  Kilométrage:-
# 1935    60000          -                  Kilométrage:-
# 2138   220000          -                  Kilométrage:-
# 2476   150000          -                  Kilométrage:-
# 2669   250000          -                  Kilométrage:-
# 2720    50000          -                  Kilométrage:-
# 2898    37000          -                  Kilométrage:-
# 3236    35000          -                  Kilométrage:-
# 3328    94000          -                  Kilométrage:-
# 3415    80000          -                  Kilométrage:-
# 3533   150000          -                  Kilométrage:-
# 3655    38000          -                  Kilométrage:-
# 3804    35000          -                  Kilométrage:-
# 3881  2400000          -                  Kilométrage:-
# 4133    55000          -                  Kilométrage:-
# 4239   125000          -  Kilométrage:150 000 - 159 999
# 4437    18000          -                  Kilométrage:-
# 4441    18000          -                  Kilométrage:-
# ...       ...        ...                            ...
# 6631    40000          -                  Kilométrage:-
# 6703    35000          -                  Kilométrage:-
# 6908    63000          -                  Kilométrage:-
# 6921    61000          -                  Kilométrage:-
# 7011    50000          -                  Kilométrage:-
# 7022    62000          -                  Kilométrage:-
# 7044    94000          -                  Kilométrage:-
# 7047    50000          -                  Kilométrage:-
# 7160   146500          -  Kilométrage:120 000 - 129 999
# 7180    95000          -                  Kilométrage:-
# 7187   135000          -                  Kilométrage:-
# 7236    70000          -                  Kilométrage:-
# 7247   170000          -                  Kilométrage:-
# 7277    72000          -                  Kilométrage:-
# 7465    57000          -                  Kilométrage:-
# 7790    90000          -                  Kilométrage:-
# 7792    52000          -                  Kilométrage:-
# 7835    32000          -                  Kilométrage:-
# 7861    38000          -                  Kilométrage:-
# 7874    65000          -                  Kilométrage:-
# 7920    62000          -                  Kilométrage:-
# 8084    93000          -                  Kilométrage:-
# 8106    60000          -                  Kilométrage:-
# 8189    99000          -                  Kilométrage:-
# 8211    97000          -                  Kilométrage:-
# 8239    25000          -                  Kilométrage:-
# 8290    57000          -                  Kilométrage:-
# 8403    60000          -                  Kilométrage:-
# 8559    59000          -                  Kilométrage:-
# 8635    30000          -                  Kilométrage:-
#
#                      fuel_type               mark                     model  \
# 140        Type de carburant:-           Marque:-                  Modèle:-
# 154        Type de carburant:-           Marque:-                  Modèle:-
# 384        Type de carburant:-           Marque:-                  Modèle:-
# 567        Type de carburant:-           Marque:-                  Modèle:-
# 587        Type de carburant:-           Marque:-                  Modèle:-
# 1017       Type de carburant:-           Marque:-                  Modèle:-
# 1073       Type de carburant:-           Marque:-                  Modèle:-
# 1140       Type de carburant:-           Marque:-                  Modèle:-
# 1177       Type de carburant:-           Marque:-                  Modèle:-
# 1237       Type de carburant:-           Marque:-                  Modèle:-
# 1413       Type de carburant:-           Marque:-                  Modèle:-
# 1498  Type de carburant:Diesel  Marque:Land Rover  Modèle:Range Rover Sport
# 1896       Type de carburant:-           Marque:-                  Modèle:-
# 1935       Type de carburant:-           Marque:-                  Modèle:-
# 2138       Type de carburant:-           Marque:-                  Modèle:-
# 2476       Type de carburant:-           Marque:-                  Modèle:-
# 2669       Type de carburant:-           Marque:-                  Modèle:-
# 2720       Type de carburant:-           Marque:-                  Modèle:-
# 2898       Type de carburant:-           Marque:-                  Modèle:-
# 3236       Type de carburant:-           Marque:-                  Modèle:-
# 3328       Type de carburant:-           Marque:-                  Modèle:-
# 3415       Type de carburant:-           Marque:-                  Modèle:-
# 3533       Type de carburant:-           Marque:-                  Modèle:-
# 3655       Type de carburant:-           Marque:-                  Modèle:-
# 3804       Type de carburant:-           Marque:-                  Modèle:-
# 3881       Type de carburant:-           Marque:-                  Modèle:-
# 4133       Type de carburant:-           Marque:-                  Modèle:-
# 4239  Type de carburant:Diesel      Marque:Toyota              Modèle:VERSO
# 4437       Type de carburant:-           Marque:-                  Modèle:-
# 4441       Type de carburant:-           Marque:-                  Modèle:-
# ...                        ...                ...                       ...
# 6631       Type de carburant:-           Marque:-                  Modèle:-
# 6703       Type de carburant:-           Marque:-                  Modèle:-
# 6908       Type de carburant:-           Marque:-                  Modèle:-
# 6921       Type de carburant:-           Marque:-                  Modèle:-
# 7011       Type de carburant:-           Marque:-                  Modèle:-
# 7022       Type de carburant:-           Marque:-                  Modèle:-
# 7044       Type de carburant:-           Marque:-                  Modèle:-
# 7047       Type de carburant:-           Marque:-                  Modèle:-
# 7160       Type de carburant:-  Marque:Volkswagen            Modèle:Touareg
# 7180       Type de carburant:-           Marque:-                  Modèle:-
# 7187       Type de carburant:-           Marque:-                  Modèle:-
# 7236       Type de carburant:-           Marque:-                  Modèle:-
# 7247       Type de carburant:-           Marque:-                  Modèle:-
# 7277       Type de carburant:-           Marque:-                  Modèle:-
# 7465       Type de carburant:-           Marque:-                  Modèle:-
# 7790       Type de carburant:-           Marque:-                  Modèle:-
# 7792       Type de carburant:-           Marque:-                  Modèle:-
# 7835       Type de carburant:-           Marque:-                  Modèle:-
# 7861       Type de carburant:-           Marque:-                  Modèle:-
# 7874       Type de carburant:-           Marque:-                  Modèle:-
# 7920       Type de carburant:-           Marque:-                  Modèle:-
# 8084       Type de carburant:-           Marque:-                  Modèle:-
# 8106       Type de carburant:-           Marque:-                  Modèle:-
# 8189       Type de carburant:-           Marque:-                  Modèle:-
# 8211       Type de carburant:-           Marque:-                  Modèle:-
# 8239       Type de carburant:-           Marque:-                  Modèle:-
# 8290       Type de carburant:-           Marque:-                  Modèle:-
# 8403       Type de carburant:-           Marque:-                  Modèle:-
# 8559       Type de carburant:-           Marque:-                  Modèle:-
# 8635       Type de carburant:-           Marque:-                  Modèle:-
#
#                  fiscal_power                 sector                  type  \
# 140       Puissance fiscale:-                      -  Type:Voitures, Offre
# 154       Puissance fiscale:-                      -  Type:Voitures, Offre
# 384       Puissance fiscale:-                      -  Type:Voitures, Offre
# 567       Puissance fiscale:-                      -  Type:Voitures, Offre
# 587       Puissance fiscale:-                      -  Type:Voitures, Offre
# 1017      Puissance fiscale:-                      -  Type:Voitures, Offre
# 1073      Puissance fiscale:-     Secteur:hay_chmaou  Type:Voitures, Offre
# 1140      Puissance fiscale:-  Secteur:administratif  Type:Voitures, Offre
# 1177      Puissance fiscale:-                      -  Type:Voitures, Offre
# 1237      Puissance fiscale:-                      -  Type:Voitures, Offre
# 1413      Puissance fiscale:-                      -  Type:Voitures, Offre
# 1498  Puissance fiscale:15 CV    Secteur:ouled_oujih  Type:Voitures, Offre
# 1896      Puissance fiscale:-                      -  Type:Voitures, Offre
# 1935      Puissance fiscale:-                      -  Type:Voitures, Offre
# 2138      Puissance fiscale:-                      -  Type:Voitures, Offre
# 2476      Puissance fiscale:-                      -  Type:Voitures, Offre
# 2669      Puissance fiscale:-                      -  Type:Voitures, Offre
# 2720      Puissance fiscale:-                      -  Type:Voitures, Offre
# 2898      Puissance fiscale:-                      -  Type:Voitures, Offre
# 3236      Puissance fiscale:-                      -  Type:Voitures, Offre
# 3328      Puissance fiscale:-                      -  Type:Voitures, Offre
# 3415      Puissance fiscale:-         Secteur:hassan  Type:Voitures, Offre
# 3533      Puissance fiscale:-                      -  Type:Voitures, Offre
# 3655      Puissance fiscale:-                      -  Type:Voitures, Offre
# 3804      Puissance fiscale:-                      -  Type:Voitures, Offre
# 3881      Puissance fiscale:-                      -  Type:Voitures, Offre
# 4133      Puissance fiscale:-                      -  Type:Voitures, Offre
# 4239   Puissance fiscale:8 CV         Secteur:wilaya  Type:Voitures, Offre
# 4437      Puissance fiscale:-                      -  Type:Voitures, Offre
# 4441      Puissance fiscale:-                      -  Type:Voitures, Offre
# ...                       ...                    ...                   ...
# 6631      Puissance fiscale:-                      -  Type:Voitures, Offre
# 6703      Puissance fiscale:-                      -  Type:Voitures, Offre
# 6908      Puissance fiscale:-                      -  Type:Voitures, Offre
# 6921      Puissance fiscale:-      Secteur:bernoussi  Type:Voitures, Offre
# 7011      Puissance fiscale:-                      -  Type:Voitures, Offre
# 7022      Puissance fiscale:-                      -  Type:Voitures, Offre
# 7044      Puissance fiscale:-                      -  Type:Voitures, Offre
# 7047      Puissance fiscale:-                      -  Type:Voitures, Offre
# 7160      Puissance fiscale:-      Secteur:ain_sebaa  Type:Voitures, Offre
# 7180      Puissance fiscale:-                      -  Type:Voitures, Offre
# 7187      Puissance fiscale:-   Secteur:centre_ville  Type:Voitures, Offre
# 7236      Puissance fiscale:-                      -  Type:Voitures, Offre
# 7247      Puissance fiscale:-                      -  Type:Voitures, Offre
# 7277      Puissance fiscale:-                      -  Type:Voitures, Offre
# 7465      Puissance fiscale:-                      -  Type:Voitures, Offre
# 7790      Puissance fiscale:-                      -  Type:Voitures, Offre
# 7792      Puissance fiscale:-                      -  Type:Voitures, Offre
# 7835      Puissance fiscale:-                      -  Type:Voitures, Offre
# 7861      Puissance fiscale:-                      -  Type:Voitures, Offre
# 7874      Puissance fiscale:-                      -  Type:Voitures, Offre
# 7920      Puissance fiscale:-                      -  Type:Voitures, Offre
# 8084      Puissance fiscale:-                      -  Type:Voitures, Offre
# 8106      Puissance fiscale:-                      -  Type:Voitures, Offre
# 8189      Puissance fiscale:-                      -  Type:Voitures, Offre
# 8211      Puissance fiscale:-                      -  Type:Voitures, Offre
# 8239      Puissance fiscale:-                      -  Type:Voitures, Offre
# 8290      Puissance fiscale:-                      -  Type:Voitures, Offre
# 8403      Puissance fiscale:-                      -  Type:Voitures, Offre
# 8559      Puissance fiscale:-                      -  Type:Voitures, Offre
# 8635      Puissance fiscale:-                      -  Type:Voitures, Offre
#
#               city
# 140         Arfoud
# 154         Dakhla
# 384        Guercif
# 567          Rabat
# 587     Casablanca
# 1017       Skhirat
# 1073          Salé
# 1140        Tanger
# 1177    Casablanca
# 1237       Skhirat
# 1413    Casablanca
# 1498       Kénitra
# 1896         Nador
# 1935    Casablanca
# 2138           Fès
# 2476    Mohammedia
# 2669      Bir Jdid
# 2720    Casablanca
# 2898        Dakhla
# 3236        Tanger
# 3328    Casablanca
# 3415         Rabat
# 3533    Casablanca
# 3655           Fès
# 3804         Rabat
# 3881         Oujda
# 4133      Khénifra
# 4239       Tétouan
# 4437     El Jadida
# 4441     El Jadida
# ...            ...
# 6631           Fès
# 6703     Ain Aouda
# 6908    Casablanca
# 6921    Casablanca
# 7011         Rabat
# 7022       Larache
# 7044    Casablanca
# 7047         Rabat
# 7160    Casablanca
# 7180      Ait Baha
# 7187    Mohammedia
# 7236    Casablanca
# 7247    Casablanca
# 7277    Casablanca
# 7465       Kénitra
# 7790        Agadir
# 7792          Salé
# 7835        Agadir
# 7861    Casablanca
# 7874   Béni Mellal
# 7920    Errachidia
# 8084           Fès
# 8106        Meknès
# 8189     Marrakech
# 8211        Agadir
# 8239    Casablanca
# 8290        Meknès
# 8403           Fès
# 8559           Fès
# 8635          Salé
#
# [88 rows x 10 columns]

# %% [markdown]
# __NOTE:__ There's still entries with no year.

# %%
df = df[df.year_model != '-']
df = df[df.year_model != ' -']
df.year_model.map(lambda x: x.isdigit() == False).sum()            # check rest of the values
# Out:
# 0

# %%
### Cast to Int
df.year_model = df.year_model.astype(int)

# %% [markdown]
# ### Fix `mileage`

# %%
# remove thos rows doesn't contain the year_model value
df = df[df.mileage.str.contains("Kilométrage") == True]

# remove the 'Kilométrage:' string from the mileage feature 
df.mileage = df.mileage.map(lambda x: x.lstrip('Kilométrage:'))
df.mileage = df.mileage.map(lambda x: x.lstrip('Plus de '))

# remove those lines having the mileage values null or '-'
df = df[df.mileage != '-']
df = df[df.mileage != ' -']

df.head()
# Out:
#     price  year_model            mileage                  fuel_type  \
# 0  135000        2013  160 000 - 169 999   Type de carburant:Diesel
# 1   53000        2008    35 000 - 39 999   Type de carburant:Diesel
# 2   59000        2007  180 000 - 189 999   Type de carburant:Diesel
# 3   88000        2010    35 000 - 39 999   Type de carburant:Diesel
# 4   60000        2009  130 000 - 139 999  Type de carburant:Essence
#
#                    mark          model            fiscal_power  \
# 0        Marque:Peugeot     Modèle:508     Puissance fiscale:-
# 1        Marque:Renault    Modèle:Clio     Puissance fiscale:-
# 2        Marque:Citroen      Modèle:C3  Puissance fiscale:6 CV
# 3  Marque:Mercedes-Benz     Modèle:220     Puissance fiscale:-
# 4           Marque:Ford  Modèle:Fiesta  Puissance fiscale:7 CV
#
#              sector                  type     city
# 0                 -  Type:Voitures, Offre   Temara
# 1                 -  Type:Voitures, Offre     Safi
# 2  Secteur:oued_fes  Type:Voitures, Offre      Fès
# 3                 -  Type:Voitures, Offre    Nador
# 4     Secteur:saies  Type:Voitures, Offre      Fès

# %%
False in df.mileage.str.contains('-')
# Out:
# True

# %%
df[df.mileage.str.contains('-') == False]
# Out:
#        price  year_model  mileage                  fuel_type  \
# 136    35000        2001  500 000   Type de carburant:Diesel
# 304    45000        1994  500 000   Type de carburant:Diesel
# 389    20200        1993  500 000   Type de carburant:Diesel
# 645    60000        1990  500 000   Type de carburant:Diesel
# 766    60000        1993  500 000   Type de carburant:Diesel
# 1006   40000        1998  500 000   Type de carburant:Diesel
# 1233   20000        1987  500 000  Type de carburant:Essence
# 1255   37000        1998  500 000  Type de carburant:Essence
# 1433   37000        1999  500 000   Type de carburant:Diesel
# 1856   39000        2000  500 000   Type de carburant:Diesel
# 2032   35000        2002  500 000  Type de carburant:Essence
# 3159   40200        1988  500 000   Type de carburant:Diesel
# 3178   47000        1999  500 000   Type de carburant:Diesel
# 3263   20000        1988  500 000  Type de carburant:Essence
# 3624   20000        1986  500 000  Type de carburant:Essence
# 4127   15000        1984  500 000   Type de carburant:Diesel
# 4565   85000        1997  500 000   Type de carburant:Diesel
# 4732   30000        1980  500 000   Type de carburant:Diesel
# 4759   56000        1994  500 000   Type de carburant:Diesel
# 4762   12000        1984  500 000  Type de carburant:Essence
# 4933   28000        1997  500 000  Type de carburant:Essence
# 5173   18000        1982  500 000   Type de carburant:Diesel
# 5184   18000        1993  500 000  Type de carburant:Essence
# 5187   39000        1986  500 000   Type de carburant:Diesel
# 5219   25000        1987  500 000   Type de carburant:Diesel
# 5243   55000        1994  500 000   Type de carburant:Diesel
# 5300   25000        1991  500 000   Type de carburant:Diesel
# 5796   60000        2002  500 000   Type de carburant:Diesel
# 5883   27000        1987  500 000   Type de carburant:Diesel
# 6122   53000        2006  500 000   Type de carburant:Diesel
# 6133   46000        2002  500 000   Type de carburant:Diesel
# 6676   25000        1993  500 000  Type de carburant:Essence
# 6690   40000        1987  500 000   Type de carburant:Diesel
# 6695   80000        2001  500 000   Type de carburant:Diesel
# 6731    9000        1984  500 000  Type de carburant:Essence
# 6847   45000        1981  500 000  Type de carburant:Essence
# 6946   41000        1990  500 000   Type de carburant:Diesel
# 7342   30000        1980  500 000  Type de carburant:Essence
# 7776  100000        2008  500 000   Type de carburant:Diesel
# 7880   35000        1999  500 000   Type de carburant:Diesel
# 7993   35000        1995  500 000   Type de carburant:Diesel
# 8392   60000        2000  500 000   Type de carburant:Diesel
# 8550   54000        1988  500 000   Type de carburant:Diesel
# 8631   25000        1993  500 000   Type de carburant:Diesel
#
#                       mark            model             fiscal_power  \
# 136            Marque:Fiat     Modèle:Palio      Puissance fiscale:-
# 304         Marque:Renault        Modèle:19      Puissance fiscale:-
# 389            Marque:Fiat       Modèle:Uno      Puissance fiscale:-
# 645         Marque:Renault    Modèle:Trafic      Puissance fiscale:-
# 766   Marque:Mercedes-Benz       Modèle:250  Puissance fiscale:10 CV
# 1006        Marque:Renault    Modèle:Laguna      Puissance fiscale:-
# 1233        Marque:Peugeot       Modèle:205      Puissance fiscale:-
# 1255        Marque:Peugeot       Modèle:306      Puissance fiscale:-
# 1433           Marque:Fiat       Modèle:Uno      Puissance fiscale:-
# 1856        Marque:Renault        Modèle:19      Puissance fiscale:-
# 2032        Marque:Peugeot       Modèle:406      Puissance fiscale:-
# 3159        Marque:Peugeot       Modèle:405      Puissance fiscale:-
# 3178        Marque:Peugeot       Modèle:406      Puissance fiscale:-
# 3263           Marque:Fiat       Modèle:Uno      Puissance fiscale:-
# 3624        Marque:Peugeot       Modèle:309      Puissance fiscale:-
# 4127        Marque:Peugeot       Modèle:205      Puissance fiscale:-
# 4565  Marque:Mercedes-Benz  Modèle:Classe C   Puissance fiscale:9 CV
# 4732  Marque:Mercedes-Benz       Modèle:240      Puissance fiscale:-
# 4759        Marque:Renault       Modèle:R19   Puissance fiscale:7 CV
# 4762        Marque:Renault       Modèle:R11      Puissance fiscale:-
# 4933     Marque:Mitsubishi    Modèle:lancer      Puissance fiscale:-
# 5173        Marque:Renault       Modèle:R18      Puissance fiscale:-
# 5184        Marque:Hyundai     Modèle:EXCEL      Puissance fiscale:-
# 5187  Marque:Mercedes-Benz       Modèle:190      Puissance fiscale:-
# 5219        Marque:Peugeot       Modèle:205      Puissance fiscale:-
# 5243        Marque:Renault       Modèle:R19   Puissance fiscale:7 CV
# 5300        Marque:Peugeot       Modèle:205      Puissance fiscale:-
# 5796        Marque:Renault    Modèle:Kangoo      Puissance fiscale:-
# 5883        Marque:Peugeot       Modèle:309   Puissance fiscale:7 CV
# 6122        Marque:Peugeot   Modèle:Partner      Puissance fiscale:-
# 6133           Marque:Fiat     Modèle:Palio      Puissance fiscale:-
# 6676        Marque:Renault        Modèle:19   Puissance fiscale:7 CV
# 6690  Marque:Mercedes-Benz       Modèle:190  Puissance fiscale:10 CV
# 6695     Marque:Volkswagen    Modèle:GOLF 4      Puissance fiscale:-
# 6731        Marque:Renault        Modèle:R9   Puissance fiscale:6 CV
# 6847  Marque:Mercedes-Benz       Modèle:300  Puissance fiscale:21 CV
# 6946     Marque:Volkswagen     Modèle:Jetta   Puissance fiscale:7 CV
# 7342        Marque:Renault        Modèle:R4      Puissance fiscale:-
# 7776        Marque:Hyundai       Modèle:H-1      Puissance fiscale:-
# 7880        Marque:Citroen       Modèle:C15      Puissance fiscale:-
# 7993  Marque:Mercedes-Benz       Modèle:300      Puissance fiscale:-
# 8392  Marque:Mercedes-Benz       Modèle:270      Puissance fiscale:-
# 8550  Marque:Mercedes-Benz       Modèle:250      Puissance fiscale:-
# 8631        Marque:Peugeot       Modèle:205      Puissance fiscale:-
#
#                       sector                  type          city
# 136                        -  Type:Voitures, Offre    Casablanca
# 304   Secteur:toute_la_ville  Type:Voitures, Offre        Tiznit
# 389                        -  Type:Voitures, Offre    Casablanca
# 645                        -  Type:Voitures, Offre           Fès
# 766       Secteur:beausejour  Type:Voitures, Offre    Casablanca
# 1006                       -  Type:Voitures, Offre           Fès
# 1233       Secteur:ben_msick  Type:Voitures, Offre    Casablanca
# 1255                       -  Type:Voitures, Offre          Salé
# 1433                       -  Type:Voitures, Offre        Temara
# 1856                       -  Type:Voitures, Offre        Meknès
# 2032       Secteur:boukhalef  Type:Voitures, Offre        Tanger
# 3159   Secteur:autre_secteur  Type:Voitures, Offre        Meknès
# 3178       Secteur:al_kasaba  Type:Voitures, Offre        Tanger
# 3263  Secteur:toute_la_ville  Type:Voitures, Offre   Had Soualem
# 3624                       -  Type:Voitures, Offre        Settat
# 4127                       -  Type:Voitures, Offre         Rabat
# 4565         Secteur:tan_tan  Type:Voitures, Offre       Tan-Tan
# 4732    Secteur:centre_ville  Type:Voitures, Offre     Marrakech
# 4759  Secteur:toute_la_ville  Type:Voitures, Offre         Azrou
# 4762                       -  Type:Voitures, Offre       Skhirat
# 4933                       -  Type:Voitures, Offre    Casablanca
# 5173       Secteur:marjane_2  Type:Voitures, Offre        Meknès
# 5184                       -  Type:Voitures, Offre          Salé
# 5187                       -  Type:Voitures, Offre        Meknès
# 5219                       -  Type:Voitures, Offre     Marrakech
# 5243           Secteur:saies  Type:Voitures, Offre           Fès
# 5300                       -  Type:Voitures, Offre    Casablanca
# 5796  Secteur:hay_oued_dahab  Type:Voitures, Offre          Salé
# 5883       Secteur:ben_msick  Type:Voitures, Offre    Casablanca
# 6122                       -  Type:Voitures, Offre           Fès
# 6133      Secteur:sidi_abbad  Type:Voitures, Offre     Marrakech
# 6676       Secteur:ben_msick  Type:Voitures, Offre    Casablanca
# 6690         Secteur:massira  Type:Voitures, Offre     Marrakech
# 6695        Secteur:el_houda  Type:Voitures, Offre        Agadir
# 6731      Secteur:sidi_taibi  Type:Voitures, Offre       Kénitra
# 6847    Secteur:centre_ville  Type:Voitures, Offre         Nador
# 6946  Secteur:toute_la_ville  Type:Voitures, Offre          Taza
# 7342  Secteur:toute_la_ville  Type:Voitures, Offre        Tiznit
# 7776     Secteur:bin_lkchali  Type:Voitures, Offre     Marrakech
# 7880    Secteur:el_bassatine  Type:Voitures, Offre        Meknès
# 7993                       -  Type:Voitures, Offre         Rabat
# 8392   Secteur:maghreb_arabi  Type:Voitures, Offre        Temara
# 8550                       -  Type:Voitures, Offre        Deroua
# 8631                       -  Type:Voitures, Offre           Fès

# %% [markdown]
# As we can see, there are many cars which do not show a range.<br>
# We have to get average for those who do, and then combine them with those cars with `500000` mileage.

# %%
# Split dataset into cars with 500,000 and those with a range

mileage50 = df[df.mileage == '500 000']
mileage50.mileage = mileage50.mileage.str.replace(' ', '')

df = df[df.mileage != '500 000']

df[df.mileage.str.contains('-') == False]
# Out:
# /home/javr/.miniconda3/envs/cpp-original/lib/python3.7/site-packages/pandas/core/generic.py:4405: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# Empty DataFrame
# Columns: [price, year_model, mileage, fuel_type, mark, model, fiscal_power, sector, type, city]
# Index: []

# %%
# we will now create a max and min for mileage.

df['min_mil'], df['max_mil'] = df.mileage.str.split('-', 1).str
# remove spaces from the maxim & minim values 
df['max_mil'] = df.max_mil.str.replace(" ","")
df['min_mil'] = df.min_mil.str.replace(" ","")
df['max_mil'] = df['max_mil'].replace(np.nan, 500000)

# calculate the mean of mileage 
df.mileage = df.apply(lambda row: (int(row.min_mil) + int(row.max_mil)) / 2, axis=1)

# now that the mileage is calculated so we do not need the minim and maxim values anymore
df = df.drop(columns=['min_mil', 'max_mil'])

# %%
df.head()
# Out:
#     price  year_model   mileage                  fuel_type  \
# 0  135000        2013  164999.5   Type de carburant:Diesel
# 1   53000        2008   37499.5   Type de carburant:Diesel
# 2   59000        2007  184999.5   Type de carburant:Diesel
# 3   88000        2010   37499.5   Type de carburant:Diesel
# 4   60000        2009  134999.5  Type de carburant:Essence
#
#                    mark          model            fiscal_power  \
# 0        Marque:Peugeot     Modèle:508     Puissance fiscale:-
# 1        Marque:Renault    Modèle:Clio     Puissance fiscale:-
# 2        Marque:Citroen      Modèle:C3  Puissance fiscale:6 CV
# 3  Marque:Mercedes-Benz     Modèle:220     Puissance fiscale:-
# 4           Marque:Ford  Modèle:Fiesta  Puissance fiscale:7 CV
#
#              sector                  type     city
# 0                 -  Type:Voitures, Offre   Temara
# 1                 -  Type:Voitures, Offre     Safi
# 2  Secteur:oued_fes  Type:Voitures, Offre      Fès
# 3                 -  Type:Voitures, Offre    Nador
# 4     Secteur:saies  Type:Voitures, Offre      Fès

# %%
df = pd.concat([df, mileage50])
df.head()
# Out:
#     price  year_model  mileage                  fuel_type  \
# 0  135000        2013   165000   Type de carburant:Diesel
# 1   53000        2008  37499.5   Type de carburant:Diesel
# 2   59000        2007   185000   Type de carburant:Diesel
# 3   88000        2010  37499.5   Type de carburant:Diesel
# 4   60000        2009   135000  Type de carburant:Essence
#
#                    mark          model            fiscal_power  \
# 0        Marque:Peugeot     Modèle:508     Puissance fiscale:-
# 1        Marque:Renault    Modèle:Clio     Puissance fiscale:-
# 2        Marque:Citroen      Modèle:C3  Puissance fiscale:6 CV
# 3  Marque:Mercedes-Benz     Modèle:220     Puissance fiscale:-
# 4           Marque:Ford  Modèle:Fiesta  Puissance fiscale:7 CV
#
#              sector                  type     city
# 0                 -  Type:Voitures, Offre   Temara
# 1                 -  Type:Voitures, Offre     Safi
# 2  Secteur:oued_fes  Type:Voitures, Offre      Fès
# 3                 -  Type:Voitures, Offre    Nador
# 4     Secteur:saies  Type:Voitures, Offre      Fès

# %%
df.mileage = pd.to_numeric(df.mileage, errors='raise', downcast='float')

# %%
df.mileage.head()
# Out:
# 0    164999.5
# 1     37499.5
# 2    184999.5
# 3     37499.5
# 4    134999.5
# Name: mileage, dtype: float32

# %% [markdown]
# ### Fix `fuel_type`

# %%
df.fuel_type = df.fuel_type.str.replace('Type de carburant:', '')
df.head()
# Out:
#     price  year_model   mileage fuel_type                  mark  \
# 0  135000        2013  164999.5    Diesel        Marque:Peugeot
# 1   53000        2008   37499.5    Diesel        Marque:Renault
# 2   59000        2007  184999.5    Diesel        Marque:Citroen
# 3   88000        2010   37499.5    Diesel  Marque:Mercedes-Benz
# 4   60000        2009  134999.5   Essence           Marque:Ford
#
#            model            fiscal_power            sector  \
# 0     Modèle:508     Puissance fiscale:-                 -
# 1    Modèle:Clio     Puissance fiscale:-                 -
# 2      Modèle:C3  Puissance fiscale:6 CV  Secteur:oued_fes
# 3     Modèle:220     Puissance fiscale:-                 -
# 4  Modèle:Fiesta  Puissance fiscale:7 CV     Secteur:saies
#
#                    type     city
# 0  Type:Voitures, Offre   Temara
# 1  Type:Voitures, Offre     Safi
# 2  Type:Voitures, Offre      Fès
# 3  Type:Voitures, Offre    Nador
# 4  Type:Voitures, Offre      Fès

# %%
df.head()
# Out:
#     price  year_model   mileage fuel_type                  mark  \
# 0  135000        2013  164999.5    Diesel        Marque:Peugeot
# 1   53000        2008   37499.5    Diesel        Marque:Renault
# 2   59000        2007  184999.5    Diesel        Marque:Citroen
# 3   88000        2010   37499.5    Diesel  Marque:Mercedes-Benz
# 4   60000        2009  134999.5   Essence           Marque:Ford
#
#            model            fiscal_power            sector  \
# 0     Modèle:508     Puissance fiscale:-                 -
# 1    Modèle:Clio     Puissance fiscale:-                 -
# 2      Modèle:C3  Puissance fiscale:6 CV  Secteur:oued_fes
# 3     Modèle:220     Puissance fiscale:-                 -
# 4  Modèle:Fiesta  Puissance fiscale:7 CV     Secteur:saies
#
#                    type     city
# 0  Type:Voitures, Offre   Temara
# 1  Type:Voitures, Offre     Safi
# 2  Type:Voitures, Offre      Fès
# 3  Type:Voitures, Offre    Nador
# 4  Type:Voitures, Offre      Fès

# %% [markdown]
# ### Fix `mark`

# %%
# remove rows that don't have the year_model value
df = df[df.mark.str.contains("Marque") == True]

# remove the 'Kilométrage:' string from the mileage feature 
df.mark = df.mark.map(lambda x: x.lstrip('Marque:'))

# %%
df[df.mark.str.contains('-')]
# Out:
#        price  year_model   mileage fuel_type        mark  \
# 3      88000        2010   37499.5    Diesel  cedes-Benz
# 17     58000        1993  224999.5    Diesel  cedes-Benz
# 27    120000        2006    2499.5    Diesel  cedes-Benz
# 37    195000        2009  224999.5   Essence  cedes-Benz
# 45    248000        2011  124999.5    Diesel  cedes-Benz
# 46     50000        1988    2499.5    Diesel  cedes-Benz
# 51     58000        1996  374999.5    Diesel  cedes-Benz
# 62    650000        2003  184999.5    Diesel  cedes-Benz
# 67     65000        1997  424999.5    Diesel  cedes-Benz
# 103   125000        2010  194999.5    Diesel  cedes-Benz
# 110    65000        1992  184999.5    Diesel  cedes-Benz
# 119   100000        2002  274999.5    Diesel  cedes-Benz
# 123    56000        1992  114999.5    Diesel  cedes-Benz
# 164   210000        2009  164999.5    Diesel  cedes-Benz
# 177    62000        1994   22499.5    Diesel  cedes-Benz
# 181    83000        2000  194999.5   Essence  cedes-Benz
# 201   228000        2009  184999.5    Diesel  cedes-Benz
# 202   228000        2014  184999.5    Diesel  cedes-Benz
# 260    95000        2001  184999.5    Diesel  cedes-Benz
# 268   195000        2013   82499.5    Diesel  cedes-Benz
# 285    30000        2016   22499.5    Diesel  cedes-Benz
# 313   175000        2008  144999.5    Diesel  cedes-Benz
# 316    43000        1997  184999.5   Essence  cedes-Benz
# 320   250000        2010   37499.5   Essence  cedes-Benz
# 327    48000        1996   22499.5    Diesel  cedes-Benz
# 334   269000        2012  114999.5    Diesel  cedes-Benz
# 362   489000        2016   17499.5    Diesel  cedes-Benz
# 376    85000        2003  154999.5    Diesel  cedes-Benz
# 380    63000        2006  324999.5    Diesel  cedes-Benz
# 392    68000        1991  324999.5    Diesel  cedes-Benz
# ...      ...         ...       ...       ...         ...
# 8282   65000        1995  224999.5   Essence  cedes-Benz
# 8284  130000        1980  134999.5    Diesel  cedes-Benz
# 8289   72000        2010  224999.5    Diesel  cedes-Benz
# 8308   85000        2005  184999.5    Diesel  cedes-Benz
# 8329   65000        1992  164999.5    Diesel  cedes-Benz
# 8330   32000        1994  144999.5    Diesel  cedes-Benz
# 8393  200000        2011  164999.5    Diesel  cedes-Benz
# 8396   67000        1995  374999.5    Diesel  cedes-Benz
# 8415   96000        2001  324999.5    Diesel  cedes-Benz
# 8419   85000        1997  324999.5    Diesel  cedes-Benz
# 8422  490000        2015   67499.5    Diesel  cedes-Benz
# 8444   79000        2002  194999.5    Diesel  cedes-Benz
# 8450  440000        2014   52499.5    Diesel  cedes-Benz
# 8452   45000        1988  324999.5    Diesel  cedes-Benz
# 8480   63000        1997   67499.5    Diesel  cedes-Benz
# 8541  115000        2007  144999.5    Diesel  cedes-Benz
# 8580  740000        2017    7499.5    Diesel  cedes-Benz
# 8583  118000        2004  374999.5    Diesel  cedes-Benz
# 8593   45000        1985  224999.5    Diesel  cedes-Benz
# 8617  105000        2002  224999.5    Diesel  cedes-Benz
# 8662   37000        1986  144999.5    Diesel  cedes-Benz
# 766    60000        1993  500000.0    Diesel  cedes-Benz
# 4565   85000        1997  500000.0    Diesel  cedes-Benz
# 4732   30000        1980  500000.0    Diesel  cedes-Benz
# 5187   39000        1986  500000.0    Diesel  cedes-Benz
# 6690   40000        1987  500000.0    Diesel  cedes-Benz
# 6847   45000        1981  500000.0   Essence  cedes-Benz
# 7993   35000        1995  500000.0    Diesel  cedes-Benz
# 8392   60000        2000  500000.0    Diesel  cedes-Benz
# 8550   54000        1988  500000.0    Diesel  cedes-Benz
#
#                       model             fiscal_power  \
# 3                Modèle:220      Puissance fiscale:-
# 17               Modèle:190   Puissance fiscale:8 CV
# 27          Modèle:Classe B      Puissance fiscale:-
# 37               Modèle:220      Puissance fiscale:-
# 45    Modèle:CLASSE C COUPE   Puissance fiscale:9 CV
# 46               Modèle:190      Puissance fiscale:-
# 51               Modèle:250  Puissance fiscale:10 CV
# 62               Modèle:270      Puissance fiscale:-
# 67               Modèle:210   Puissance fiscale:9 CV
# 103              Modèle:220      Puissance fiscale:-
# 110              Modèle:190   Puissance fiscale:8 CV
# 119         Modèle:Classe C   Puissance fiscale:9 CV
# 123              Modèle:190   Puissance fiscale:8 CV
# 164       Modèle:Classe CLS  Puissance fiscale:12 CV
# 177              Modèle:190      Puissance fiscale:-
# 181              Modèle:220      Puissance fiscale:-
# 201              Modèle:220      Puissance fiscale:-
# 202              Modèle:220   Puissance fiscale:9 CV
# 260              Modèle:220      Puissance fiscale:-
# 268         Modèle:Classe B   Puissance fiscale:8 CV
# 285              Modèle:220      Puissance fiscale:-
# 313              Modèle:220      Puissance fiscale:-
# 316              Modèle:230  Puissance fiscale:11 CV
# 320         Modèle:Classe E      Puissance fiscale:-
# 327         Modèle:Classe C      Puissance fiscale:-
# 334         Modèle:Classe E      Puissance fiscale:-
# 362         Modèle:Classe E      Puissance fiscale:-
# 376         Modèle:Classe C   Puissance fiscale:8 CV
# 380              Modèle:220      Puissance fiscale:-
# 392              Modèle:190   Puissance fiscale:8 CV
# ...                     ...                      ...
# 8282        Modèle:Classe C      Puissance fiscale:-
# 8284            Modèle:207D  Puissance fiscale:10 CV
# 8289             Modèle:220      Puissance fiscale:-
# 8308             Modèle:220   Puissance fiscale:8 CV
# 8329             Modèle:190      Puissance fiscale:-
# 8330             Modèle:408      Puissance fiscale:-
# 8393             Modèle:220      Puissance fiscale:-
# 8396             Modèle:220      Puissance fiscale:-
# 8415        Modèle:Classe E      Puissance fiscale:-
# 8419             Modèle:220      Puissance fiscale:-
# 8422             Modèle:220      Puissance fiscale:-
# 8444            Modèle:Vito      Puissance fiscale:-
# 8450        Modèle:Classe C      Puissance fiscale:-
# 8452             Modèle:190      Puissance fiscale:-
# 8480             Modèle:250      Puissance fiscale:-
# 8541        Modèle:Classe C   Puissance fiscale:8 CV
# 8580        Modèle:Classe E   Puissance fiscale:9 CV
# 8583             Modèle:220   Puissance fiscale:9 CV
# 8593             Modèle:190   Puissance fiscale:8 CV
# 8617             Modèle:220      Puissance fiscale:-
# 8662             Modèle:190      Puissance fiscale:-
# 766              Modèle:250  Puissance fiscale:10 CV
# 4565        Modèle:Classe C   Puissance fiscale:9 CV
# 4732             Modèle:240      Puissance fiscale:-
# 5187             Modèle:190      Puissance fiscale:-
# 6690             Modèle:190  Puissance fiscale:10 CV
# 6847             Modèle:300  Puissance fiscale:21 CV
# 7993             Modèle:300      Puissance fiscale:-
# 8392             Modèle:270      Puissance fiscale:-
# 8550             Modèle:250      Puissance fiscale:-
#
#                                 sector                  type  \
# 3                                    -  Type:Voitures, Offre
# 17              Secteur:toute_la_ville  Type:Voitures, Offre
# 27                Secteur:jnan_el_ward  Type:Voitures, Offre
# 37                                   -  Type:Voitures, Offre
# 45                  Secteur:californie  Type:Voitures, Offre
# 46                                   -  Type:Voitures, Offre
# 51               Secteur:autre_secteur  Type:Voitures, Offre
# 62                                   -  Type:Voitures, Offre
# 67                   Secteur:ain_chock  Type:Voitures, Offre
# 103             Secteur:toute_la_ville  Type:Voitures, Offre
# 110                  Secteur:ben_souda  Type:Voitures, Offre
# 119                Secteur:hay_lazaret  Type:Voitures, Offre
# 123                                  -  Type:Voitures, Offre
# 164                     Secteur:maarif  Type:Voitures, Offre
# 177                                  -  Type:Voitures, Offre
# 181                                  -  Type:Voitures, Offre
# 201                     Secteur:2_mars  Type:Voitures, Offre
# 202                      Secteur:oulfa  Type:Voitures, Offre
# 260                                  -  Type:Voitures, Offre
# 268                     Secteur:2_mars  Type:Voitures, Offre
# 285                                  -  Type:Voitures, Offre
# 313                   Secteur:al_kodia  Type:Voitures, Offre
# 316                      Secteur:sbata  Type:Voitures, Offre
# 320                       Secteur:anfa  Type:Voitures, Offre
# 327                   Secteur:selouane  Type:Voitures, Offre
# 334                       Secteur:anfa  Type:Voitures, Offre
# 362                       Secteur:anfa  Type:Voitures, Offre
# 376           Secteur:route_dimmouzere  Type:Voitures, Offre
# 380              Secteur:autre_secteur  Type:Voitures, Offre
# 392              Secteur:autre_secteur  Type:Voitures, Offre
# ...                                ...                   ...
# 8282                   Secteur:al_fida  Type:Voitures, Offre
# 8284                                 -  Type:Voitures, Offre
# 8289                                 -  Type:Voitures, Offre
# 8308                 Secteur:hay_inara  Type:Voitures, Offre
# 8329                                 -  Type:Voitures, Offre
# 8330                 Secteur:hay_rahma  Type:Voitures, Offre
# 8393                                 -  Type:Voitures, Offre
# 8396                                 -  Type:Voitures, Offre
# 8415            Secteur:toute_la_ville  Type:Voitures, Offre
# 8419            Secteur:toute_la_ville  Type:Voitures, Offre
# 8422                                 -  Type:Voitures, Offre
# 8444                                 -  Type:Voitures, Offre
# 8450              Secteur:centre_ville  Type:Voitures, Offre
# 8452                 Secteur:zerhounia  Type:Voitures, Offre
# 8480                                 -  Type:Voitures, Offre
# 8541                 Secteur:ain_sebaa  Type:Voitures, Offre
# 8580                    Secteur:maarif  Type:Voitures, Offre
# 8583                     Secteur:oulfa  Type:Voitures, Offre
# 8593                    Secteur:2_mars  Type:Voitures, Offre
# 8617  Secteur:zone_industrielle_agadir  Type:Voitures, Offre
# 8662                                 -  Type:Voitures, Offre
# 766                 Secteur:beausejour  Type:Voitures, Offre
# 4565                   Secteur:tan_tan  Type:Voitures, Offre
# 4732              Secteur:centre_ville  Type:Voitures, Offre
# 5187                                 -  Type:Voitures, Offre
# 6690                   Secteur:massira  Type:Voitures, Offre
# 6847              Secteur:centre_ville  Type:Voitures, Offre
# 7993                                 -  Type:Voitures, Offre
# 8392             Secteur:maghreb_arabi  Type:Voitures, Offre
# 8550                                 -  Type:Voitures, Offre
#
#                     city
# 3                  Nador
# 17                Tifelt
# 27                   Fès
# 37             El Jadida
# 45            Casablanca
# 46             El Jadida
# 51                 Rabat
# 62                 Rabat
# 67            Casablanca
# 103    Kelaat Es-Sraghna
# 110                  Fès
# 119                Oujda
# 123           Casablanca
# 164           Casablanca
# 177           Casablanca
# 181               Tanger
# 201           Casablanca
# 202           Casablanca
# 260                Rabat
# 268           Casablanca
# 285               Temara
# 313            El Jadida
# 316           Casablanca
# 320           Casablanca
# 327                Nador
# 334           Casablanca
# 362           Casablanca
# 376                  Fès
# 380            El Jadida
# 392                  Fès
# ...                  ...
# 8282          Casablanca
# 8284              Dakhla
# 8289               Rabat
# 8308          Casablanca
# 8329             Tétouan
# 8330                Salé
# 8393          Casablanca
# 8396                 Fès
# 8415          Al Hoceïma
# 8419             Berkane
# 8422              Meknès
# 8444                Salé
# 8450               Nador
# 8452              Meknès
# 8480                Salé
# 8541          Casablanca
# 8580          Casablanca
# 8583          Casablanca
# 8593          Casablanca
# 8617              Agadir
# 8662             Missour
# 766           Casablanca
# 4565             Tan-Tan
# 4732           Marrakech
# 5187              Meknès
# 6690           Marrakech
# 6847               Nador
# 7993               Rabat
# 8392              Temara
# 8550              Deroua
#
# [600 rows x 10 columns]

# %%
df.mark = df.mark.str.replace('cedes-Benz', 'Mercedes Benz')

# %%
df[df.mark.str.contains('-')]
# Out:
#       price  year_model   mileage fuel_type mark     model  \
# 1294  63000        2013  124999.5         -    -  Modèle:-
# 7232  30000        1981   32499.5         -    -  Modèle:-
#
#              fiscal_power            sector                  type     city
# 1294  Puissance fiscale:-                 -  Type:Voitures, Offre   Tanger
# 7232  Puissance fiscale:-  Secteur:al_aroui  Type:Voitures, Offre    Nador

# %%
df = df[df.mark != '-']

# %%
df.head()
# Out:
#     price  year_model   mileage fuel_type           mark          model  \
# 0  135000        2013  164999.5    Diesel        Peugeot     Modèle:508
# 1   53000        2008   37499.5    Diesel        Renault    Modèle:Clio
# 2   59000        2007  184999.5    Diesel        Citroen      Modèle:C3
# 3   88000        2010   37499.5    Diesel  Mercedes Benz     Modèle:220
# 4   60000        2009  134999.5   Essence           Ford  Modèle:Fiesta
#
#              fiscal_power            sector                  type     city
# 0     Puissance fiscale:-                 -  Type:Voitures, Offre   Temara
# 1     Puissance fiscale:-                 -  Type:Voitures, Offre     Safi
# 2  Puissance fiscale:6 CV  Secteur:oued_fes  Type:Voitures, Offre      Fès
# 3     Puissance fiscale:-                 -  Type:Voitures, Offre    Nador
# 4  Puissance fiscale:7 CV     Secteur:saies  Type:Voitures, Offre      Fès

# %%
df[df.mark.str.contains('-')]
# Out:
# Empty DataFrame
# Columns: [price, year_model, mileage, fuel_type, mark, model, fiscal_power, sector, type, city]
# Index: []

# %%
df.head()
# Out:
#     price  year_model   mileage fuel_type           mark          model  \
# 0  135000        2013  164999.5    Diesel        Peugeot     Modèle:508
# 1   53000        2008   37499.5    Diesel        Renault    Modèle:Clio
# 2   59000        2007  184999.5    Diesel        Citroen      Modèle:C3
# 3   88000        2010   37499.5    Diesel  Mercedes Benz     Modèle:220
# 4   60000        2009  134999.5   Essence           Ford  Modèle:Fiesta
#
#              fiscal_power            sector                  type     city
# 0     Puissance fiscale:-                 -  Type:Voitures, Offre   Temara
# 1     Puissance fiscale:-                 -  Type:Voitures, Offre     Safi
# 2  Puissance fiscale:6 CV  Secteur:oued_fes  Type:Voitures, Offre      Fès
# 3     Puissance fiscale:-                 -  Type:Voitures, Offre    Nador
# 4  Puissance fiscale:7 CV     Secteur:saies  Type:Voitures, Offre      Fès

# %% [markdown]
# ### Fix `model`

# %%
# remove rows that don't have the year_model value
df = df[df.model.str.contains("Modèle:") == True]
df = df[df.mark != '-']
df = df[df.mark != ' -']
df.model = df.model.map( lambda x: x.lstrip('Modèle:'))

# %% [markdown]
# ### Fix `fiscal_power`

# %% [markdown]
# <p class="lead">For the fiscal power we can see that there is exactly 5728 rows not announced, so we will fill them by the mean of the other columns, since it is an important feature in cars price prediction so we can not drop it.</p>

# %%
df.fiscal_power.value_counts()
# Out:
# Puissance fiscale:-                5624
# Puissance fiscale:6 CV             1011
# Puissance fiscale:8 CV              692
# Puissance fiscale:7 CV              495
# Puissance fiscale:9 CV              207
# Puissance fiscale:11 CV             115
# Puissance fiscale:10 CV             109
# Puissance fiscale:5 CV              107
# Puissance fiscale:12 CV             103
# Puissance fiscale:4 CV               22
# Puissance fiscale:17 CV              14
# Puissance fiscale:13 CV              11
# Puissance fiscale:21 CV               8
# Puissance fiscale:-                   6
# Puissance fiscale:20 CV               5
# Puissance fiscale:23 CV               4
# Puissance fiscale:14 CV               3
# Puissance fiscale:Plus de 48 CV       3
# Puissance fiscale:40 CV               2
# Puissance fiscale:15 CV               2
# Puissance fiscale:26 CV               2
# Puissance fiscale:18 CV               2
# Puissance fiscale:29 CV               2
# Puissance fiscale:24 CV               1
# Puissance fiscale:31 CV               1
# Puissance fiscale:16 CV               1
# Puissance fiscale:34 CV               1
# Puissance fiscale:28 CV               1
# Puissance fiscale:19 CV               1
# Puissance fiscale:39 CV               1
# Name: fiscal_power, dtype: int64

# %%
# remove the 'Puissance fiscale:' from the fiscal_power feature
df.fiscal_power = df.fiscal_power.map(lambda x: x.lstrip('Puissance fiscale:Plus de').rstrip(' CV'))

# replace the - with NaN values and convert them to integer values
df.fiscal_power = df.fiscal_power.str.replace("-","0")

# convert all fiscal_power values to numerical ones 
df.fiscal_power = pd.to_numeric(df.fiscal_power, errors = 'coerce', downcast= 'integer')

# now we need to fill those 0 values with the mean of all fiscal_power columns
df.fiscal_power = df.fiscal_power.map( lambda x : df.fiscal_power.mean() if x == 0 else x )

# %% [markdown]
# ### `sector` and `type`
# <p class="lead">the sector, type and city features are not needed to build this model so we will delete them defintely, since they are not very representative in this case, for the model categorical feature we will drop it because of the hugeamount of levels.</p>

# %%
df = df.drop(columns=['sector', 'type'])
df.head()
# Out:
#     price  year_model   mileage fuel_type           mark   model  \
# 0  135000        2013  164999.5    Diesel        Peugeot     508
# 1   53000        2008   37499.5    Diesel        Renault    Clio
# 2   59000        2007  184999.5    Diesel        Citroen      C3
# 3   88000        2010   37499.5    Diesel  Mercedes Benz     220
# 4   60000        2009  134999.5   Essence           Ford  Fiesta
#
#    fiscal_power     city
# 0      2.631837   Temara
# 1      2.631837     Safi
# 2      6.000000      Fès
# 3      2.631837    Nador
# 4      7.000000      Fès

# %% [markdown]
# ### Save clean data!

# %%
# CLEANED_FILENAME = "./data/cleaned.csv"
# df.to_csv(CLEANED_FILENAME)

# %% [markdown]
# <center><h1 id="epa">Exploratory Data Analysis</h1></center>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Load clean dataset

df = pd.read_csv(CLEANDED_FILENAME)

# %% [markdown]
# ## Price Distribution by `year_model`
# <p class="lead">Let's visualize the distribution of cars price by their year model release, and look how it behaves</p>

# %%
# here we set the figure size to 15x8
plt.figure(figsize=(15, 8))

# plot two values price per year_model
plt.scatter(df.price, df.year_model)
plt.xlabel("price (DH)", fontsize=14)
plt.ylabel("year of model", fontsize=14)
plt.title("Scatter plot of price and year of model",fontsize=18)
plt.show()

# %% [markdown]
# <center><h1>Model Creation</h1></center>
